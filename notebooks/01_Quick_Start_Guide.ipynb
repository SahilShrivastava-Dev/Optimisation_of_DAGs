# %% [markdown]
# # 🚀 DAG Optimizer - Quick Start Guide
#
# This notebook demonstrates how to use the `dagoptimizer` Python library for optimizing Directed Acyclic Graphs (DAGs).
#
# **Author:** Sahil Shrivastava
# **Library:** dagoptimizer
# **GitHub:** https://github.com/SahilShrivastava-Dev/Optimisation_of_DAGs
#
# ## What You'll Learn
#
# 1. Installation and setup
# 2. Basic transitive reduction
# 3. ML pipeline optimization
# 4. PERT/CPM critical path analysis
# 5. Layer analysis (parallelism)
# 6. Edge criticality
# 7. Comprehensive metrics
# 8. Visualization
